# %% [markdown]
# <a href="https://colab.research.google.com/github/bsekercioglu/introduction-to-python/blob/newBranch11/HomeWork1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
odd= list(range(1,10,2))
even= list(range(0,10,2))
print (odd)
print (even)
item=[]
for x in even:item.append(x*2)
for x in odd:item.append(x*2)
item.sort()
for y in item:print(f"{y} türü={type(y)}")
# Out:
# [1, 3, 5, 7, 9]
# [0, 2, 4, 6, 8]
# 0 türü=<class 'int'>
# 2 türü=<class 'int'>
# 4 türü=<class 'int'>
# 6 türü=<class 'int'>
# 8 türü=<class 'int'>
# 10 türü=<class 'int'>
# 12 türü=<class 'int'>
# 14 türü=<class 'int'>
# 16 türü=<class 'int'>
# 18 türü=<class 'int'>
